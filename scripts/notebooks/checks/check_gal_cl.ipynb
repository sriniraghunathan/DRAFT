# %%
# %load_ext autoreload
# %autoreload 2

#%pylab notebook
# %matplotlib inline
from pylab import *
#from matplotlib import rc;rc('text', usetex=True);rc('font', weight='bold');matplotlib.rcParams['text.latex.preamble'] = r'\boldmath'
rcParams["figure.facecolor"] = 'white'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rcParams['figure.dpi'] = 150

# %%
import sys, numpy as np, scipy as sc, warnings, os#, healpy as H
sys.path.append('/Users/sraghunathan/Research/SPTPol/analysis/git/DRAFT/modules/')
import foregrounds as fg, misc

#import matplotlib.cbook
warnings.filterwarnings('ignore',category=RuntimeWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=matplotlib.cbook.mplDeprecation)

# %%
#params
TParr = ['T', 'P']
which_spec = 'TT'
#which_spec = 'EE'
#which_spec = 'BB'
#which_spec = 'TE'
#which_spec = 'EB'

param_dict = {}

#param_dict['cl_gal_dic_dust_fname'] = 'cls_galactic_sims_dust_CUmilta_20200319_planck_mask.npy'
#param_dict['cl_gal_dic_sync_fname'] = 'cls_galactic_sims_sync_CUmilta_20200319_planck_mask.npy'
#param_dict['cl_gal_dic_dust_fname'] = 'cls_galactic_sims_dust_CUmilta_20200319_maskplanck.npy'

'''
nside, lmax = 2048, 3500
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/galactic/CUmilta/ampmod_maps/'
#param_dict['cl_gal_dic_dust_fname'] = 'data/cls_galactic_sims_dust_CUmilta_20200319_maskplanck_nside%s_lmax%s_mask%s.npy' %(nside, lmax, which_mask)
#param_dict['cl_gal_dic_sync_fname'] = 'data/cls_galactic_sims_sync_CUmilta_20200319_maskplanck_nside%s_lmax%s_mask%s.npy' %(nside, lmax, which_mask)
param_dict['cl_gal_dic_dust_fname'] = '%s/cls_galactic_sims_dust_CUmilta_20200319_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/cls_galactic_sims_sync_CUmilta_20200319_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
extra_str = 'CUmilta_sims/planck_mask/'
'''


'''
#AZonca sims
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/cls_galactic_sims_dust_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/cls_galactic_sims_sync_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
'''

'''
#for cluster survey: T-only
nside, lmax = 4096, 7000
TParr = ['T']
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/lat_steps/cls_galactic_sims_dust_maskplanck_nside%s_lmax%s_TTonly.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/lat_steps/cls_galactic_sims_sync_maskplanck_nside%s_lmax%s_TTonly.npy' %(data_folder, nside, lmax)
extra_str = 'AZonca_sims/planck_mask/'
'''

'''
#for Neff: T/P available
nside, lmax = 4096, 7000
TParr = ['T', 'P']
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/s4like_mask/cls_galactic_sims_dust_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/s4like_mask/cls_galactic_sims_sync_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
extra_str = 'pySM3/s4like_mask/'
'''

#for Neff: T/P available
nside, lmax = 2048, 5000
TParr = ['T', 'P']
#which_sim_set = '202002_foregrounds_extragalactic_cmb_tophat'
which_sim_set = '202102_design_tool_input'
if (1): #S4-wide
    '''
    #data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/%s/4096/' %(which_sim_set)
    data_folder = 'tmp/s4/cmbs4/map_based_simulations/%s/4096/' %(which_sim_set)
    param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
    param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/s4like_mask_v2/cls_galactic_sims_sync_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
    extra_str = 'pySM3/s4like_mask_v2/'
    '''
    use_planck_mask = False #True #False #True
    data_folder = 'tmp/s4/cmbs4/map_based_simulations/%s/4096/' %(which_sim_set)
    if use_planck_mask:
        param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/planck_mask/cls_galactic_sims_dust_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
        param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/planck_mask/cls_galactic_sims_sync_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
        extra_str = 'pySM3/planck_mask/'
    else:
        param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
        param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/s4like_mask_v2/cls_galactic_sims_sync_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
        extra_str = 'pySM3/s4like_mask_v2/'
    
if (0): #S4-delensing
    data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/%s/4096/' %(which_sim_set)
    data_folder = 'tmp/s4/cmbs4/map_based_simulations/%s/4096/' %(which_sim_set)
    param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/s4delensing_mask/cls_galactic_sims_dust_nside%s_lmax%s_delensing.npy' %(data_folder, nside, lmax)
    param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/s4delensing_mask/cls_galactic_sims_sync_nside%s_lmax%s_delensing.npy' %(data_folder, nside, lmax)
    extra_str = 'pySM3/s4delensing_mask/'


'''
#spt3g masks
nside, lmax = 2048, 6000
TParr = ['T', 'P']
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/spt3g/cls_galactic_sims_dust_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/spt3g/cls_galactic_sims_sync_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
extra_str = 'pySM3/spt3g/'
'''

if (0):
    #S4 specs
    specs_dic = {
    #freq: [beam_arcmins, white_noise_T, elknee_T, alphaknee_T, whitenoise_P, elknee_P, alphaknee_P] 
    #20: [10.0, None, None, None, None, None, None],
    #27: [7.4, 21.8, 471., 3.5, 30.8, 700, 1.4],
    #39: [5.1, 12.4, 428., 3.5, 17.6, 700, 1.4], 
    93: [2.2, 2.0, 2154., 3.5, 2.9, 700, 1.4],
    145: [1.4, 2.0, 4364., 3.5, 2.8, 700, 1.4],
    225: [1.0, 6.9, 7334., 3.5, 9.8, 700, 1.4],
    278: [0.9, 16.7, 7308., 3.5, 23.6, 700, 1.4],
    }
    freqarr = sorted( specs_dic.keys() )

param_dict['lmax'] = lmax
param_dict['Dlfile_len'] = '/Users/sraghunathan/Research/SPTPol/analysis/git/DRAFT/data/output_planck_r_0.0_2015_cosmo_lensedCls.dat'

# %%
#CAMB output for plotting
camb_file = param_dict['Dlfile_len']
Tcmb = 2.725
el_camb = np.loadtxt(camb_file, usecols = [0])
dl_camb = np.loadtxt(camb_file, usecols = [1,2,3,4])

cl_camb = ( Tcmb**2. * dl_camb * 2 * np.pi ) / ( el_camb[:,None] * (el_camb[:,None] + 1) )
cl_camb *= 1e12
cl_TT, cl_EE, cl_BB, cl_TE = cl_camb.T

# %%
mask_str_dic = None
clf()
fig = figure(figsize=(10., 4.4))
subplots_adjust(wspace=0.05)
freqarr = [93, 145] ##278]
#alpha_dic = {93: 0.3, 145: 0.6, 225: 0.8, 278: 1.}
alpha_dic = {93: .5, 145: 1., 225: 1., 278: 1.}
lw_dic = {93: 1., 145: 1., 225: 1.5, 278: 2.}
ls_dic = {93: '-.', 145: '-', 225: '--', 278: ':'}

tot_mask_iter = 4
color_dic = {0:'navy', 1: 'green', 2: 'goldenrod', 3: 'darkred'}

tot_mask_iter = 5
color_dic = {0:'navy', 1: 'green', 2: 'goldenrod', 3: 'orangered', 4: 'darkred'}

tot_mask_iter = 4
color_dic = {0:'navy', 1: 'green', 2: 'goldenrod', 3: 'darkred'}
reqd_masks = []
if extra_str.find('s4like_mask_v2')>-1 or extra_str.find('s4delensing')>-1 or extra_str.find('planck_mask')>-1:
    tot_mask_iter = 6
    
    if extra_str.find('s4delensing')>-1:
        reqd_masks = [0]
    else:
        if extra_str.find('planck_mask')>-1:
            reqd_masks = [0, 1, 2]
        else:
            reqd_masks = [0, 1, 2, 3, 4, 5]
    #color_dic = {0:'navy', 1: 'darkblue', 2: 'royalblue', 3: 'orangered', 4: 'darkred', 5: 'maroon'}
    cmap = cm.jet
    color_dic = {0:cmap(0), 1: cmap(15), 2: cmap(30), 3: cmap(230), 4: cmap(240), 5: cmap(255)}
    if (1):
        color_dic = {0: 'navy', 1: 'darkgreen', 2: 'red', 3: 'silver', 4: 'gray', 5: 'black'}
    freqarr = [145]
    which_spec = 'TT' #EE' #TT'
if extra_str.find('spt3g')>-1:
    tot_mask_iter = 4
    reqd_masks = [0, 1, 2, 3]
    #color_dic = {0:'navy', 1: 'darkblue', 2: 'royalblue', 3: 'orangered', 4: 'darkred', 5: 'maroon'}
    cmap = cm.jet
    color_dic = {0: 'navy', 1: 'darkred', 2: 'darkgreen', 3: 'goldenrod'}
    mask_str_dic = {0: 'Winter', 1: 'Summer: el1c-el2c', 2: 'Summer: el1b-el2b', 3: 'Summer: el1-el5'}
    freqarr = [145]
    which_spec = 'EE' #'TT'


#xscale_val = 'log' ##None#'log' #None
use_sed_scaling = False
xscale_val = None
for mask_iter in range(tot_mask_iter):
    if len(reqd_masks)>0:
        if mask_iter not in reqd_masks: continue
    plot_done = []
    for freq1 in freqarr:
        for freq2 in freqarr:
            

            if (freq1, freq2) in plot_done: continue
                
            if freq1 != freq2: continue
                
            try:
                el, cl_dust = fg.get_cl_galactic(param_dict, 'dust', freq1, freq2, which_spec = which_spec, which_gal_mask = mask_iter, use_sed_scaling = use_sed_scaling)
            except:
                cl_dust = None
                
            try:
                el, cl_sync = fg.get_cl_galactic(param_dict, 'sync', freq1, freq2, which_spec = which_spec, which_gal_mask = mask_iter, use_sed_scaling = use_sed_scaling)
            except:
                cl_sync = None
                
            if freq1 == 93:
                delta_ell = 50
            elif freq1 == 145:
                delta_ell = 100                         
            el_to_plot = np.arange(min(el), max(el)+1, delta_ell)

            plot_done.append((freq1, freq2))
            lab = '%s: (%s,%s)' %(mask_iter, freq1, freq2)

            lwval = lw_dic[freq1]
            colorval = color_dic[mask_iter]
            alphaval = alpha_dic[freq1]
            lsval = ls_dic[freq1]
            #lwval = 1.
            lab = None
            if cl_dust is not None:
                cl_dust_to_plot = np.interp(el_to_plot, el, cl_dust)
                ax = subplot(1,2,1, yscale = 'log', xscale=xscale_val)
                plot(el, cl_dust, label = lab, lw = 0.5, linestyle = lsval, color = colorval, alpha = alphaval)
                #plot(el_to_plot, cl_dust_to_plot, label = lab, lw = lwval, linestyle = lsval, color = colorval, alpha = alphaval)
            if cl_sync is not None:
                cl_sync_to_plot = np.interp(el_to_plot, el, cl_sync)                            
                ax = subplot(1,2,2, yscale = 'log', xscale=xscale_val)
                plot(el, cl_sync, label = lab, lw = 0.5, linestyle = lsval, color = colorval, alpha = alphaval)
                #plot(el_to_plot, cl_sync_to_plot, label = lab, lw = lwval, linestyle = lsval, color = colorval, alpha = alphaval)

for cntr, which_comp in enumerate( ['dust', 'sync'] ):
    
    ax = subplot(1,2,cntr+1, yscale = 'log', xscale=xscale_val)
    if which_spec == 'TT':
        plot(el_camb, cl_TT, 'gray', lw = 2., label = r'%s' %(which_spec), alpha = 0.3, zorder = -1000.)
    elif which_spec == 'EE':
        plot(el_camb, cl_EE, 'gray', lw = 2., label = r'%s' %(which_spec), alpha = 0.3, zorder = -1000.)
    elif which_spec == 'TE':
        plot(el_camb, cl_TE, 'gray', lw = 2., label = r'%s' %(which_spec), alpha = 0.3, zorder = -1000.)
        plot(el_camb, abs( cl_TE ), 'gray', ls = '--', lw = 2., alpha = 0.3, zorder = -1000.)        
    elif which_spec == 'BB':
        plot(el_camb, cl_BB, 'gray', lw = 2., label = r'%s' %(which_spec), alpha = 0.3, zorder = -1000.)
    if cntr == 1: ##0:

        galdustsims_cl = np.load(param_dict['cl_gal_dic_dust_fname'], allow_pickle=1, encoding = 'latin1').item()
        fsky_arr = galdustsims_cl['fsky_arr']
        if len(freqarr)>1:
            for freq1 in freqarr:
                plot([], [], color = 'k', alpha = alpha_dic[freq1], ls = ls_dic[freq1], label = r'%s GHz' %(freq1))
        for mask_iter in range(tot_mask_iter):
            if len(reqd_masks)>0:
                if mask_iter not in reqd_masks: continue
            fsky_val = fsky_arr[mask_iter]
            labval = r'Mask %s: f$_{\rm sky} = %.2f$' %(mask_iter, fsky_val)
            if mask_str_dic is not None:
                labval = r'Mask %s (%s): f$_{\rm sky} = %.2f$' %(mask_iter, mask_str_dic[mask_iter], fsky_val)
            plot([], [], color = color_dic[mask_iter], label = labval)
            
        #legend(loc = 3, ncol = 2, fontsize = 8)
        legend(loc = 1, ncol = 1, fontsize = 8)
    xlabel(r'Multipole $\ell$', fontsize = 14)
    if cntr == 0:
        ylabel(r'$C_{\ell}\ [\mu {\rm K}^{2}]$', fontsize = 14)
    else:
        setp(ax.get_yticklabels(which = 'both'), visible=False)
    extra_str_tmp = extra_str.split('/')[0].replace('_', '\_')
    if len(freqarr)>1:
        title(r'%s: %s (%s)' %(which_spec, which_comp.capitalize(), extra_str_tmp), fontsize = 11)
    else:
        title(r'%s: %s (%s): %s GHz' %(which_spec, which_comp.capitalize(), extra_str_tmp, freqarr[0]), fontsize = 11)
    xmax = 5000#7100 #lmax+100
    xlim(-100, xmax); 
    ylim(1e-10, 1e4)
    if (1):
        ylim(1e-8, .1)
        grid(which = 'both', axis = 'both', lw = 0.05)
    
    if (0):
        xlim(-100, 3000); 
        ylim(1e-5, 1e2)
        grid(which = 'both', axis = 'both', lw = 0.1)
        

    #xlim(None, 200); ylim(1e-6, 1e-2)
if use_planck_mask:
    mask_str = r'{\it Planck} mask'
else:
    mask_str = r'Lat-based mask'
suptitle('%s; Sim set = %s' %(mask_str, which_sim_set.replace('_','\_')), fontsize = 14, y = 1.02)
show();sys.exit()
plfolder = 'reports/galactic_sims/dust_sync_spectra/%s/' %(extra_str)
os.system('mkdir -p %s' %(plfolder))
#savefig('%s/dust_sync_%s.pdf' %(plfolder, which_spec))
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3449: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
fg.get_cl_galactic??

# %%
#params
TParr = ['T', 'P']

param_dict = {}

#param_dict['cl_gal_dic_dust_fname'] = 'cls_galactic_sims_dust_CUmilta_20200319_planck_mask.npy'
#param_dict['cl_gal_dic_sync_fname'] = 'cls_galactic_sims_sync_CUmilta_20200319_planck_mask.npy'
#param_dict['cl_gal_dic_dust_fname'] = 'cls_galactic_sims_dust_CUmilta_20200319_maskplanck.npy'

'''
nside, lmax = 2048, 3500
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/galactic/CUmilta/ampmod_maps/'
#param_dict['cl_gal_dic_dust_fname'] = 'data/cls_galactic_sims_dust_CUmilta_20200319_maskplanck_nside%s_lmax%s_mask%s.npy' %(nside, lmax, which_mask)
#param_dict['cl_gal_dic_sync_fname'] = 'data/cls_galactic_sims_sync_CUmilta_20200319_maskplanck_nside%s_lmax%s_mask%s.npy' %(nside, lmax, which_mask)
param_dict['cl_gal_dic_dust_fname'] = '%s/cls_galactic_sims_dust_CUmilta_20200319_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/cls_galactic_sims_sync_CUmilta_20200319_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
extra_str = 'CUmilta_sims/planck_mask/'
'''


'''
#AZonca sims
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/cls_galactic_sims_dust_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/cls_galactic_sims_sync_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
'''

'''
#for cluster survey: T-only
nside, lmax = 4096, 7000
TParr = ['T']
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/lat_steps/cls_galactic_sims_dust_maskplanck_nside%s_lmax%s_TTonly.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/lat_steps/cls_galactic_sims_sync_maskplanck_nside%s_lmax%s_TTonly.npy' %(data_folder, nside, lmax)
extra_str = 'AZonca_sims/planck_mask/'
'''

'''
#for Neff: T/P available
nside, lmax = 4096, 7000
TParr = ['T', 'P']
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/s4like_mask/cls_galactic_sims_dust_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/s4like_mask/cls_galactic_sims_sync_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
extra_str = 'pySM3/s4like_mask/'
'''

#for Neff: T/P available
nside, lmax = 2048, 5000
TParr = ['T', 'P']
#which_sim_set = '202002_foregrounds_extragalactic_cmb_tophat'
which_sim_set = '202102_design_tool_input'

'''
#spt3g masks
nside, lmax = 2048, 6000
TParr = ['T', 'P']
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/spt3g/cls_galactic_sims_dust_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/spt3g/cls_galactic_sims_sync_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
extra_str = 'pySM3/spt3g/'
'''

param_dict['lmax'] = lmax
param_dict['Dlfile_len'] = '/Users/sraghunathan/Research/SPTPol/analysis/git/DRAFT/data/output_planck_r_0.0_2015_cosmo_lensedCls.dat'

# %%
#CAMB output for plotting
camb_file = param_dict['Dlfile_len']
Tcmb = 2.725
el_camb = np.loadtxt(camb_file, usecols = [0])
dl_camb = np.loadtxt(camb_file, usecols = [1,2,3,4])

cl_camb = ( Tcmb**2. * dl_camb * 2 * np.pi ) / ( el_camb[:,None] * (el_camb[:,None] + 1) )
cl_camb *= 1e12
cl_TT, cl_EE, cl_BB, cl_TE = cl_camb.T

# %%
use_sed_scaling = False #True
pl_dict = {}
fsky_dict = {}
for use_planck_mask_iter in range(2):
    pl_dict[use_planck_mask_iter] = {}
    use_planck_mask = use_planck_mask_iter        
    data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/%s/4096/' %(which_sim_set)
    data_folder = 'tmp/s4/cmbs4/map_based_simulations/%s/4096/' %(which_sim_set)
    if use_planck_mask:
        param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/planck_mask/cls_galactic_sims_dust_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
        param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/planck_mask/cls_galactic_sims_sync_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
        extra_str = 'pySM3/planck_mask/'
    else:
        param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
        param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/s4like_mask_v2/cls_galactic_sims_sync_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
        extra_str = 'pySM3/s4like_mask_v2/'


    mask_str_dic = None
    freqarr = [93, 145] ##278]
    #alpha_dic = {93: 0.3, 145: 0.6, 225: 0.8, 278: 1.}
    alpha_dic = {93: .5, 145: 1., 225: 1., 278: 1.}
    lw_dic = {93: 1., 145: 1., 225: 1.5, 278: 2.}
    ls_dic = {93: '-.', 145: '-', 225: '--', 278: ':'}

    tot_mask_iter = 4
    color_dic = {0:'navy', 1: 'green', 2: 'goldenrod', 3: 'darkred'}

    tot_mask_iter = 5
    color_dic = {0:'navy', 1: 'green', 2: 'goldenrod', 3: 'orangered', 4: 'darkred'}

    tot_mask_iter = 4
    color_dic = {0:'navy', 1: 'green', 2: 'goldenrod', 3: 'darkred'}
    reqd_masks = []
    if extra_str.find('s4like_mask_v2')>-1 or extra_str.find('s4delensing')>-1 or extra_str.find('planck_mask')>-1:
        tot_mask_iter = 6
        if extra_str.find('s4delensing')>-1:
            reqd_masks = [0]
        if extra_str.find('planck_mask')>-1:
            reqd_masks = [0, 1, 2]
        else:
            reqd_masks = [0, 1, 2, 3, 4, 5]
        #color_dic = {0:'navy', 1: 'darkblue', 2: 'royalblue', 3: 'orangered', 4: 'darkred', 5: 'maroon'}
        cmap = cm.jet
        color_dic = {0:cmap(0), 1: cmap(15), 2: cmap(30), 3: cmap(230), 4: cmap(240), 5: cmap(255)}
        freqarr = [145]
        which_spec = 'EE'#'TT' #EE' #TT'
        which_spec_arr = ['TT', 'EE']
    if extra_str.find('spt3g')>-1:
        tot_mask_iter = 4
        reqd_masks = [0, 1, 2, 3]
        #color_dic = {0:'navy', 1: 'darkblue', 2: 'royalblue', 3: 'orangered', 4: 'darkred', 5: 'maroon'}
        cmap = cm.jet
        color_dic = {0: 'navy', 1: 'darkred', 2: 'darkgreen', 3: 'goldenrod'}
        mask_str_dic = {0: 'Winter', 1: 'Summer: el1c-el2c', 2: 'Summer: el1b-el2b', 3: 'Summer: el1-el5'}
        freqarr = [145]
        which_spec = 'EE' #'TT'
        which_spec_arr = [which_spec]

    #xscale_val = 'log' ##None#'log' #None
    for which_spec in which_spec_arr:
        pl_dict[use_planck_mask_iter][which_spec] = {}
        for mask_iter in range(tot_mask_iter):
            pl_dict[use_planck_mask_iter][which_spec][mask_iter] = {}
            if len(reqd_masks)>0:
                if mask_iter not in reqd_masks: continue
            plot_done = []
            for freq1 in freqarr:
                for freq2 in freqarr:


                    if (freq1, freq2) in plot_done: continue

                    if freq1 != freq2: continue

                    print(param_dict['cl_gal_dic_dust_fname'])
                    try:
                        el, cl_dust = fg.get_cl_galactic(param_dict, 'dust', freq1, freq2, which_spec = which_spec, which_gal_mask = mask_iter, use_sed_scaling = use_sed_scaling)
                    except:
                        cl_dust = None  

                    try:
                        el, cl_sync = fg.get_cl_galactic(param_dict, 'sync', freq1, freq2, which_spec = which_spec, which_gal_mask = mask_iter, use_sed_scaling = use_sed_scaling)
                    except:
                        cl_sync = None

                    if freq1 == 93:
                        delta_ell = 50
                    elif freq1 == 145:
                        delta_ell = 100                         
                    el_to_plot = np.arange(min(el), max(el)+1, delta_ell)

                    plot_done.append((freq1, freq2))
                    lab = '%s: (%s,%s)' %(mask_iter, freq1, freq2)

                    lwval = lw_dic[freq1]
                    colorval = color_dic[mask_iter]
                    alphaval = alpha_dic[freq1]
                    lsval = ls_dic[freq1]
                    #lwval = 1.
                    lab = None
                    if cl_dust is not None:
                        cl_dust_to_plot = np.interp(el_to_plot, el, cl_dust)
                        pl_dict[use_planck_mask_iter][which_spec][mask_iter]['dust'] = cl_dust_to_plot
                    if cl_sync is not None:
                        cl_sync_to_plot = np.interp(el_to_plot, el, cl_sync)                            
                        pl_dict[use_planck_mask_iter][which_spec][mask_iter]['sync'] = cl_sync_to_plot
    galdustsims_cl = np.load(param_dict['cl_gal_dic_dust_fname'], allow_pickle=1, encoding = 'latin1').item()
    fsky_arr = galdustsims_cl['fsky_arr']
    fsky_dict[use_planck_mask_iter] = fsky_arr
# Out:
# tmp/s4/cmbs4/map_based_simulations/202102_design_tool_input/4096//dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside2048_lmax5000_cos_el_40.npy
# tmp/s4/cmbs4/map_based_simulations/202102_design_tool_input/4096//dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside2048_lmax5000_cos_el_40.npy
# tmp/s4/cmbs4/map_based_simulations/202102_design_tool_input/4096//dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside2048_lmax5000_cos_el_40.npy
# tmp/s4/cmbs4/map_based_simulations/202102_design_tool_input/4096//dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside2048_lmax5000_cos_el_40.npy
# tmp/s4/cmbs4/map_based_simulations/202102_design_tool_input/4096//dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside2048_lmax5000_cos_el_40.npy
# tmp/s4/cmbs4/map_based_simulations/202102_design_tool_input/4096//dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside2048_lmax5000_cos_el_40.npy
# ...

# %%
res_s4_mask = pl_dict[0]
res_planck_mask = pl_dict[1]
print(res_planck_mask.keys())

print('fsky is %s' %(fsky_dict))
# Out:
# dict_keys(['TT', 'EE'])
# fsky is {0: array([0.46625773, 0.51661174, 0.56968689, 0.21202596, 0.16167196,
#        0.1085968 ]), 1: array([0.48921204, 0.5530955 , 0.61932882])}

# %%
clf()
which_comp = 'dust'
ax = subplot(111, yscale = 'log')
for which_spec in ['TT']:
    plot(el_to_plot, res_s4_mask[which_spec][0][which_comp], color = 'navy')
    plot(el_to_plot, res_s4_mask[which_spec][1][which_comp], color = 'darkgreen')
    plot(el_to_plot, res_s4_mask[which_spec][2][which_comp], color = 'red')
    if (1):
        xlim(-100, 3000); 
        ylim(1e-5, 1e2)
        grid(which = 'both', axis = 'both', lw = 0.1)
show()
inds_to_print = np.where(el_to_plot>=3000)
print(el_to_plot[inds_to_print], res_s4_mask[which_spec][0][which_comp][inds_to_print])
# Out:
# [3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300
#  4400 4500 4600 4700 4800 4900 5000] [3.21488228e-05 3.18006205e-05 2.78796646e-05 2.52044282e-05
#  2.36060283e-05 2.05334088e-05 1.86245892e-05 1.74534171e-05
#  1.52993891e-05 1.53242246e-05 1.43867710e-05 1.21172317e-05
#  1.22639612e-05 1.11028756e-05 1.07736503e-05 1.01454514e-05
#  9.58507040e-06 9.83913959e-06 9.26755694e-06 8.18897960e-06
#  8.10009641e-06]

# %%
which_comp = 'dust'
ax = subplot(111, yscale = 'log')
for which_spec in ['TT']:
    plot(el_to_plot, res_planck_mask[which_spec][0][which_comp], color = 'navy')
    plot(el_to_plot, res_planck_mask[which_spec][1][which_comp], color = 'darkgreen')
    plot(el_to_plot, res_planck_mask[which_spec][2][which_comp], color = 'red')
    if (1):
        xlim(-100, 3000); 
        ylim(1e-5, 1e2)
        grid(which = 'both', axis = 'both', lw = 0.1)
    show()
inds_to_print = np.where(el_to_plot>=3000)
print(el_to_plot[inds_to_print], res_planck_mask[which_spec][0][which_comp][inds_to_print])
# Out:
# [3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300
#  4400 4500 4600 4700 4800 4900 5000] [6.94523807e-06 6.07140427e-06 5.33797995e-06 5.02156634e-06
#  4.26729914e-06 3.91430921e-06 3.55941311e-06 3.05940313e-06
#  2.85373071e-06 2.56198343e-06 2.25790201e-06 2.12950336e-06
#  1.96030215e-06 1.76530650e-06 1.70951328e-06 1.49727484e-06
#  1.43442105e-06 1.28750592e-06 1.18504151e-06 1.13488750e-06
#  9.97135001e-07]

# %%
which_comp = 'dust'
clf()
figure(figsize = (10., 4.5))
subplots_adjust(wspace=0.1)
for cntr, which_spec in enumerate(which_spec_arr):
#for which_spec in ['TT']:
    ax = subplot(1, 2, cntr+1)
    '''
    plot(el_to_plot, res_s4_mask[which_spec][0][which_comp] / res_planck_mask[which_spec][0][which_comp], color = 'navy')
    plot(el_to_plot, res_s4_mask[which_spec][1][which_comp] / res_planck_mask[which_spec][1][which_comp], color = 'darkgreen')
    plot(el_to_plot, res_s4_mask[which_spec][2][which_comp] / res_planck_mask[which_spec][2][which_comp], color = 'red')
    '''
    color_arr = ['navy', 'darkgreen', 'red']
    for maskiter in range(3):
        fsky_str = r'$f_{\rm sky}$: Lat-based = %.2f; {\it Planck} = %.2f' %(fsky_dict[0][maskiter], fsky_dict[1][maskiter])
        print(fsky_str)
        if which_spec == 'EE':
            labval = fsky_str
        else:
            labval = None
        plot(el_to_plot, res_s4_mask[which_spec][maskiter][which_comp] / res_planck_mask[which_spec][maskiter][which_comp], color = color_arr[maskiter], label = labval)
    title(r'%s: %s GHz' %(which_spec, freqarr[0]))
    if cntr == 0:
        ylabel(r'Galactic FG power ratio: Lat-based-mask / {\it Planck} mask', fontsize = 10)
    else:
        legend(loc = 1, fontsize = 12)
    xlabel(r'Multipole $\ell$', fontsize = 14)
    axhline(1., lw = 0.2)
    xlim(0., 5000.); ylim(0., 8.)
show()
# Out:
# $f_{\rm sky}$: Lat-based = 0.47; {\it Planck} = 0.49
# $f_{\rm sky}$: Lat-based = 0.52; {\it Planck} = 0.55
# $f_{\rm sky}$: Lat-based = 0.57; {\it Planck} = 0.62
# $f_{\rm sky}$: Lat-based = 0.47; {\it Planck} = 0.49
# $f_{\rm sky}$: Lat-based = 0.52; {\it Planck} = 0.55
# $f_{\rm sky}$: Lat-based = 0.57; {\it Planck} = 0.62

# %%
#params
TParr = ['T', 'P']
#which_spec = 'TT'
which_spec = 'EE'
#which_spec = 'BB'
#which_spec = 'TE'
#which_spec = 'EB'

param_dict = {}

#param_dict['cl_gal_dic_dust_fname'] = 'cls_galactic_sims_dust_CUmilta_20200319_planck_mask.npy'
#param_dict['cl_gal_dic_sync_fname'] = 'cls_galactic_sims_sync_CUmilta_20200319_planck_mask.npy'
#param_dict['cl_gal_dic_dust_fname'] = 'cls_galactic_sims_dust_CUmilta_20200319_maskplanck.npy'

'''
nside, lmax = 2048, 3500
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/galactic/CUmilta/ampmod_maps/'
#param_dict['cl_gal_dic_dust_fname'] = 'data/cls_galactic_sims_dust_CUmilta_20200319_maskplanck_nside%s_lmax%s_mask%s.npy' %(nside, lmax, which_mask)
#param_dict['cl_gal_dic_sync_fname'] = 'data/cls_galactic_sims_sync_CUmilta_20200319_maskplanck_nside%s_lmax%s_mask%s.npy' %(nside, lmax, which_mask)
param_dict['cl_gal_dic_dust_fname'] = '%s/cls_galactic_sims_dust_CUmilta_20200319_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/cls_galactic_sims_sync_CUmilta_20200319_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
extra_str = 'CUmilta_sims/planck_mask/'
'''


'''
#AZonca sims
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/cls_galactic_sims_dust_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/cls_galactic_sims_sync_maskplanck_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
'''

'''
#for cluster survey: T-only
nside, lmax = 4096, 7000
TParr = ['T']
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/lat_steps/cls_galactic_sims_dust_maskplanck_nside%s_lmax%s_TTonly.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/lat_steps/cls_galactic_sims_sync_maskplanck_nside%s_lmax%s_TTonly.npy' %(data_folder, nside, lmax)
extra_str = 'AZonca_sims/planck_mask/'
'''

'''
#for Neff: T/P available
nside, lmax = 4096, 7000
TParr = ['T', 'P']
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/s4like_mask/cls_galactic_sims_dust_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/s4like_mask/cls_galactic_sims_sync_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
extra_str = 'pySM3/s4like_mask/'
'''

#for Neff: T/P available
nside, lmax = 2048, 5000
TParr = ['T', 'P']
#which_sim_set = '202002_foregrounds_extragalactic_cmb_tophat'
which_sim_set = '202102_design_tool_input'
if (0): #S4-wide
    data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/%s/4096/' %(which_sim_set)
    param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/s4like_mask_v2/cls_galactic_sims_dust_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
    param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/s4like_mask_v2/cls_galactic_sims_sync_nside%s_lmax%s_cos_el_40.npy' %(data_folder, nside, lmax)
    extra_str = 'pySM3/s4like_mask_v2/'
if (1): #S4-delensing
    data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/%s/4096/' %(which_sim_set)
    param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/s4delensing_mask/cls_galactic_sims_dust_nside%s_lmax%s_delensing.npy' %(data_folder, nside, lmax)
    param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/s4delensing_mask/cls_galactic_sims_sync_nside%s_lmax%s_delensing.npy' %(data_folder, nside, lmax)
    extra_str = 'pySM3/s4delensing_mask/'
    

'''
#spt3g masks
nside, lmax = 2048, 6000
TParr = ['T', 'P']
data_folder = '/Volumes/data_PHD_WD_babbloo/s4/cmbs4/map_based_simulations/202002_foregrounds_extragalactic_cmb_tophat/4096/'
param_dict['cl_gal_dic_dust_fname'] = '%s/dust/0000/spt3g/cls_galactic_sims_dust_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
param_dict['cl_gal_dic_sync_fname'] = '%s/synchrotron/0000/spt3g/cls_galactic_sims_sync_nside%s_lmax%s.npy' %(data_folder, nside, lmax)
extra_str = 'pySM3/spt3g/'
'''

if (0):
    #S4 specs
    specs_dic = {
    #freq: [beam_arcmins, white_noise_T, elknee_T, alphaknee_T, whitenoise_P, elknee_P, alphaknee_P] 
    #20: [10.0, None, None, None, None, None, None],
    #27: [7.4, 21.8, 471., 3.5, 30.8, 700, 1.4],
    #39: [5.1, 12.4, 428., 3.5, 17.6, 700, 1.4], 
    93: [2.2, 2.0, 2154., 3.5, 2.9, 700, 1.4],
    145: [1.4, 2.0, 4364., 3.5, 2.8, 700, 1.4],
    225: [1.0, 6.9, 7334., 3.5, 9.8, 700, 1.4],
    278: [0.9, 16.7, 7308., 3.5, 23.6, 700, 1.4],
    }
    freqarr = sorted( specs_dic.keys() )

param_dict['lmax'] = lmax
param_dict['Dlfile_len'] = '/Users/sraghunathan/Research/SPTPol/analysis/git/DRAFT/data/output_planck_r_0.0_2015_cosmo_lensedCls.dat'

# %%
#CAMB output for plotting
camb_file = param_dict['Dlfile_len']
Tcmb = 2.725
el_camb = np.loadtxt(camb_file, usecols = [0])
dl_camb = np.loadtxt(camb_file, usecols = [1,2,3,4])

cl_camb = ( Tcmb**2. * dl_camb * 2 * np.pi ) / ( el_camb[:,None] * (el_camb[:,None] + 1) )
cl_camb *= 1e12
cl_TT, cl_EE, cl_BB, cl_TE = cl_camb.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/08/mkcy0rls72j2q09krs7qx2jw0000gn/T/ipykernel_94901/2606115128.py in <module>
#       1 #CAMB output for plotting
# ----> 2 camb_file = param_dict['Dlfile_len']
#       3 Tcmb = 2.725
#       4 el_camb = np.loadtxt(camb_file, usecols = [0])
#       5 dl_camb = np.loadtxt(camb_file, usecols = [1,2,3,4])
#
# NameError: name 'param_dict' is not defined

# %%
mask_str_dic = None
clf()
fig = figure(figsize=(8., 4.))
subplots_adjust(wspace=0.05)
freqarr = [93, 145] ##278]
#alpha_dic = {93: 0.3, 145: 0.6, 225: 0.8, 278: 1.}
alpha_dic = {93: .5, 145: 1., 225: 1., 278: 1.}
lw_dic = {93: 1., 145: 1., 225: 1.5, 278: 2.}
ls_dic = {93: '-.', 145: '-', 225: '--', 278: ':'}

tot_mask_iter = 4
color_dic = {0:'navy', 1: 'green', 2: 'goldenrod', 3: 'darkred'}

tot_mask_iter = 5
color_dic = {0:'navy', 1: 'green', 2: 'goldenrod', 3: 'orangered', 4: 'darkred'}

tot_mask_iter = 4
color_dic = {0:'navy', 1: 'green', 2: 'goldenrod', 3: 'darkred'}
reqd_masks = []
if extra_str.find('s4like_mask_v2')>-1 or extra_str.find('s4delensing')>-1:
    tot_mask_iter = 6
    if extra_str.find('s4delensing')>-1:
        reqd_masks = [0]
    else:
        reqd_masks = [0, 1, 2, 3, 4, 5]
    #color_dic = {0:'navy', 1: 'darkblue', 2: 'royalblue', 3: 'orangered', 4: 'darkred', 5: 'maroon'}
    cmap = cm.jet
    color_dic = {0:cmap(0), 1: cmap(15), 2: cmap(30), 3: cmap(230), 4: cmap(240), 5: cmap(255)}
    freqarr = [145]
    which_spec = 'EE'#'TT' #EE' #TT'
if extra_str.find('spt3g')>-1:
    tot_mask_iter = 4
    reqd_masks = [0, 1, 2, 3]
    #color_dic = {0:'navy', 1: 'darkblue', 2: 'royalblue', 3: 'orangered', 4: 'darkred', 5: 'maroon'}
    cmap = cm.jet
    color_dic = {0: 'navy', 1: 'darkred', 2: 'darkgreen', 3: 'goldenrod'}
    mask_str_dic = {0: 'Winter', 1: 'Summer: el1c-el2c', 2: 'Summer: el1b-el2b', 3: 'Summer: el1-el5'}
    freqarr = [145]
    which_spec = 'EE' #'TT'


#xscale_val = 'log' ##None#'log' #None
xscale_val = None
for mask_iter in range(tot_mask_iter):
    if len(reqd_masks)>0:
        if mask_iter not in reqd_masks: continue
    plot_done = []
    for freq1 in freqarr:
        for freq2 in freqarr:
            

            if (freq1, freq2) in plot_done: continue
                
            if freq1 != freq2: continue
                
            try:
                el, cl_dust = fg.get_cl_galactic(param_dict, 'dust', freq1, freq2, which_spec = which_spec, which_gal_mask = mask_iter)
            except:
                cl_dust = None  
                
            try:
                el, cl_sync = fg.get_cl_galactic(param_dict, 'sync', freq1, freq2, which_spec = which_spec, which_gal_mask = mask_iter)
            except:
                cl_sync = None
                
            if freq1 == 93:
                delta_ell = 50
            elif freq1 == 145:
                delta_ell = 100                         
            el_to_plot = np.arange(min(el), max(el)+1, delta_ell)

            plot_done.append((freq1, freq2))
            lab = '%s: (%s,%s)' %(mask_iter, freq1, freq2)

            lwval = lw_dic[freq1]
            colorval = color_dic[mask_iter]
            alphaval = alpha_dic[freq1]
            lsval = ls_dic[freq1]
            #lwval = 1.
            lab = None
            if cl_dust is not None:
                cl_dust_to_plot = np.interp(el_to_plot, el, cl_dust)
                ax = subplot(1,2,1, yscale = 'log', xscale=xscale_val)
                plot(el, cl_dust, label = lab, lw = 0.5, linestyle = lsval, color = colorval, alpha = alphaval)
                #plot(el_to_plot, cl_dust_to_plot, label = lab, lw = lwval, linestyle = lsval, color = colorval, alpha = alphaval)
            if cl_sync is not None:
                cl_sync_to_plot = np.interp(el_to_plot, el, cl_sync)                            
                ax = subplot(1,2,2, yscale = 'log', xscale=xscale_val)
                plot(el, cl_sync, label = lab, lw = 0.5, linestyle = lsval, color = colorval, alpha = alphaval)
                #plot(el_to_plot, cl_sync_to_plot, label = lab, lw = lwval, linestyle = lsval, color = colorval, alpha = alphaval)

for cntr, which_comp in enumerate( ['dust', 'sync'] ):
    
    ax = subplot(1,2,cntr+1, yscale = 'log', xscale=xscale_val)
    if which_spec == 'TT':
        plot(el_camb, cl_TT, 'gray', lw = 2., label = r'%s' %(which_spec), alpha = 0.3, zorder = -1000.)
    elif which_spec == 'EE':
        plot(el_camb, cl_EE, 'gray', lw = 2., label = r'%s' %(which_spec), alpha = 0.3, zorder = -1000.)
    elif which_spec == 'TE':
        plot(el_camb, cl_TE, 'gray', lw = 2., label = r'%s' %(which_spec), alpha = 0.3, zorder = -1000.)
        plot(el_camb, abs( cl_TE ), 'gray', ls = '--', lw = 2., alpha = 0.3, zorder = -1000.)        
    elif which_spec == 'BB':
        plot(el_camb, cl_BB, 'gray', lw = 2., label = r'%s' %(which_spec), alpha = 0.3, zorder = -1000.)
    if cntr == 1: ##0:

        galdustsims_cl = np.load(param_dict['cl_gal_dic_dust_fname'], allow_pickle=1, encoding = 'latin1').item()
        fsky_arr = galdustsims_cl['fsky_arr']
        if len(freqarr)>1:
            for freq1 in absfreqarr:
                plot([], [], color = 'k', alpha = alpha_dic[freq1], ls = ls_dic[freq1], label = r'%s GHz' %(freq1))
        for mask_iter in range(tot_mask_iter):
            if len(reqd_masks)>0:
                if mask_iter not in reqd_masks: continue
            fsky_val = fsky_arr[mask_iter]
            labval = r'Mask %s: f$_{\rm sky} = %.2f$' %(mask_iter, fsky_val)
            if mask_str_dic is not None:
                labval = r'Mask %s (%s): f$_{\rm sky} = %.2f$' %(mask_iter, mask_str_dic[mask_iter], fsky_val)
            plot([], [], color = color_dic[mask_iter], label = labval)
            
        #legend(loc = 3, ncol = 2, fontsize = 8)
        legend(loc = 1, ncol = 1, fontsize = 8)
    xlabel(r'Multipole $\ell$', fontsize = 14)
    if cntr == 0:
        ylabel(r'$C_{\ell}\ [\mu {\rm K}^{2}]$', fontsize = 14)
    else:
        setp(ax.get_yticklabels(which = 'both'), visible=False)
    extra_str_tmp = extra_str.split('/')[0].replace('_', '\_')
    if len(freqarr)>1:
        title(r'%s: %s (%s)' %(which_spec, which_comp.capitalize(), extra_str_tmp), fontsize = 14)
    else:
        title(r'%s: %s (%s): %s GHz' %(which_spec, which_comp.capitalize(), extra_str_tmp, freqarr[0]), fontsize = 14)
    xmax = 5000#7100 #lmax+100
    xlim(-100, xmax); 
    ylim(1e-10, 1e4)

    #xlim(None, 200); ylim(1e-6, 1e-2)
suptitle('Sim set = %s' %(which_sim_set.replace('_','\_')), fontsize = 12, y = 1.02)
show();sys.exit()
plfolder = 'reports/galactic_sims/dust_sync_spectra/%s/' %(extra_str)
os.system('mkdir -p %s' %(plfolder))
#savefig('%s/dust_sync_%s.pdf' %(plfolder, which_spec))
